# %%
import pandas as pd
import numpy as np
import ast
import json

# %%
import os

archivos_en_carpeta = os.listdir()
print(archivos_en_carpeta)
# Out:
# ['.ipynb_checkpoints', 'australian_users_items.json', 'australian_user_reviews.json', 'Diccionario de Datos STEAM.xlsx', 'output_steam_games.json', 'Untitled.ipynb', 'Untitled1.ipynb']

# %%
allNewLines = []

with open('australian_users_items.json', 'r', encoding='utf-8') as file1:
    contenido = file1.read()
    
    for line in contenido.split('\n'):
        if line.strip():
            NewDict1 = ast.literal_eval(line)
            allNewLines.append(NewDict1)

UserItemsDF = pd.DataFrame(allNewLines)

# %%
UserItemsDF.head(2)
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1            js41637          888  76561198035864385
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1               http://steamcommunity.com/id/js41637
#
#                                                items
# 0  [{'item_id': '10', 'item_name': 'Counter-Strik...
# 1  [{'item_id': '10', 'item_name': 'Counter-Strik...

# %%
allNewLines = []

with open('australian_user_reviews.json', 'r', encoding='utf-8') as file2:
    contenido = file2.read()
    
    for line in contenido.split('\n'):
        if line.strip():
            NewDict2 = ast.literal_eval(line)
            allNewLines.append(NewDict2)

UserReviewsDF = pd.DataFrame(allNewLines)

# %%
UserReviewsDF.head(5)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
all_data = []

with open('output_steam_games.json', 'r', encoding='utf-8') as file3:
    for line in file3:
        try:
            data = json.loads(line)
            all_data.append(data)
        except json.JSONDecodeError as e:
            print(f"Error al decodificar JSON en línea: {line}")
            print(f"Mensaje de error: {str(e)}")

SteamGamesDF = pd.DataFrame(all_data)

# %%
SteamGamesDF2 = pd.DataFrame(all_data)

# %%
SteamGamesDF2[SteamGamesDF2.duplicated(keep=False, subset='id')].dropna(subset='id')
# Out:
#                  publisher    genres                          app_name  \
# 102204  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
# 102883  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                    title  \
# 102204  Wolfenstein II: The New Colossus
# 102883  Wolfenstein II: The New Colossus
#
#                                                       url release_date  \
# 102204          http://store.steampowered.com/app/612880/   2017-10-26
# 102883  http://store.steampowered.com/app/612880/Wolfe...   2017-10-26
#
#                                                      tags  \
# 102204  [Action, FPS, Gore, Violent, Alternate History...
# 102883  [Action, FPS, Gore, Violent, Alternate History...
#
#                                               reviews_url  discount_price  \
# 102204  http://steamcommunity.com/app/612880/reviews/?...             NaN
# 102883  http://steamcommunity.com/app/612880/reviews/?...             NaN
#
# ...

# %%
index_last_dup_to_remove = SteamGamesDF2[SteamGamesDF2.duplicated(keep='last', subset='id')].dropna(subset='id').index

# %%
index_last_dup_to_remove
# Out:
# Int64Index([102204], dtype='int64')

# %%
SteamGamesDF2.iloc[index_last_dup_to_remove]
# Out:
#                  publisher    genres                          app_name  \
# 102204  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                    title  \
# 102204  Wolfenstein II: The New Colossus
#
#                                               url release_date  \
# 102204  http://store.steampowered.com/app/612880/   2017-10-26
#
#                                                      tags  \
# 102204  [Action, FPS, Gore, Violent, Alternate History...
#
#                                               reviews_url  discount_price  \
# 102204  http://steamcommunity.com/app/612880/reviews/?...             NaN
#
#                                                     specs  price early_access  \
# 102204  [Single-player, Steam Achievements, Full contr...  59.99        False
#
#             id metascore      developer user_id steam_id items  items_count
# 102204  612880        86  Machine Games     NaN      NaN   NaN          NaN

# %%
SteamGamesDF2.drop(index=index_last_dup_to_remove, inplace=True)

# %%
SteamGamesDF2.head(10)
# Out:
#   publisher genres app_name title  url release_date tags reviews_url  \
# 0       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 1       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 2       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 3       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 4       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 5       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 6       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 7       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 8       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
# 9       NaN    NaN      NaN   NaN  NaN          NaN  NaN         NaN
#
#    discount_price specs price early_access   id metascore developer  \
# 0             NaN   NaN   NaN          NaN  NaN       NaN       NaN
# 1             NaN   NaN   NaN          NaN  NaN       NaN       NaN
# ...

# %%
SteamGamesDF2.dropna(subset=['id'], inplace=True)

# %%
SteamGamesDF2.head(5)
# Out:
#               publisher                                             genres  \
# 88310         Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 88311  Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 88312      Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313              彼岸领域                        [Action, Adventure, Casual]
# 88314               NaN                                                NaN
#
#                       app_name                    title  \
# 88310      Lost Summoner Kitty      Lost Summoner Kitty
# 88311                Ironbound                Ironbound
# 88312  Real Pool 3D - Poolians  Real Pool 3D - Poolians
# 88313                  弹炸人2222                  弹炸人2222
# 88314            Log Challenge                      NaN
#
#                                                      url release_date  \
# 88310  http://store.steampowered.com/app/761140/Lost_...   2018-01-04
# ...

# %%
SteamGamesDF2.shape
# Out:
# (32132, 19)

# %%
SteamGamesDF2.to_csv('DataSteam2.csv', index=False)
